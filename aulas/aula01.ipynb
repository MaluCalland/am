# %%
# Declaração de variáveis do Sistema
# variavel_000 = 0
# variavel_001 = 0.0
# variavel_002 = True
# variavel_003 = 'Olá Mundo!'
# nome = 'Pedro'
# sobrenome = 'da Silva'
# nome_completo = nome + " " + sobrenome 

# print(variavel_003) 
# print('Meu primeiro programa Python!') 
# print(type(variavel_000))
# print(type(variavel_001))
# print(type(variavel_002))
# print(type(variavel_003))
# print(nome_completo)

# print(8 + 9) # soma
# print(8 - 9) # subtracao
# print(8 * 9) # multiplicacao
# print(10 / 2) # divisao real
# print(10 // 2) # divisao inteira
# print(10 % 2) # módulo (mod): resto da divisao
# print(4 ** 2) # potencialização

# Bloco de declaração de variáveis
# variavel_01 = 5 
# variavel_02 = str
# variavel_03 = 0.0
# variavel_04 = float
# variavel_05 = ' '
# variavel_06 = variavel_l_08 = True07 = variave

# lista_01 = [True, False, True, 0, 0.0]

# if (variavel_01 < 5):
#     print(variavel_01)
# elif variavel_01 == 0:
#     print(variavel_03)
# else:
#     print(type(variavel_01))

# print("tttttttttt")

# mes = int
# mes = input('Digite o mês: ') #input sempre pega string
# mes = int(input('Digite o mês: '))

# if mes == 1:
#     print('o mês é janeiro', mes)
# elif mes == 2:
#     print('o mês é fevereiro')
# else:
#     print('é depois de março')
# print(type(mes))

# mes = int(input('Digite o valor do mês: '))
# match mes:
#     case 1:
#         print('janeiro')
#     case 2:
#         print('fevereiro')
#     case 3: 
#         print('março')
#     case _:
#         print()

    
# for i in range(20,1,-1):
#     print(i)

# Declaração de variaveis
# funcionario = ['Pedro', 'Ana', 'Mariana', 'Ricardo', 'Mateus', 'Andre', 'João'] #lista
#funcionario = {'Pedro', 'Ana', 'Mariana', 'Ricardo', 'Mateus', 'Andre', 'João'} #outro tipo de variavel: dicionario

# for nome in funcionario:
#     print(nome)

# for cont_int in range(1,10):
#     print('numero:', cont_int)
#     # print('numero:' + str(cont_int))
#     # print('numero: ' + cont_int) #contatenar so do mesmo tipo
#     for cont_int2 in range(5,0,-1):
#         print(f'contagem regressiva{cont_int2}')
# print('terminou o laco for')

################## ATIVIDADE EM SALA ##################
# nota_1 = float(input('Digite sua nota P1: '))
# nota_2 = float(input('Digite sua nota P2: '))

# print(f'Nota da P1: {nota_1}')
# print(f'Nota da P2: {nota_2}')

# mediaNotas = (nota_1 + nota_2)/2
# print(f'Média: {mediaNotas}')

# if mediaNotas >= 5.0: 
#     print('Aprovado. Sua média foi igual a ' + str(mediaNotas))
# elif mediaNotas >= 2.0:
#     print(f'Está de Recuperação. Sua média foi igual a {mediaNotas}')
# else:
#     print(f'Reprovado. Sua média foi igual a {mediaNotas:.2f}')

from getpass import getpass
# senha_1 = input("digite sua senha: ")
senha_1 = getpass("digite sua senha: ")
print(senha_1)
# Out:
# 2314290066
